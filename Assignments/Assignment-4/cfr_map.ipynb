# %%
# Corina Eveleigh
# Student Number 100549940
# please see README.txt

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from JSAnimation.IPython_display import display_animation
import urllib
from mpl_toolkits.basemap import Basemap

# %%
import csv 

dt = np.dtype([('category', 'U15'), ('lat', float), ('long', float), ('cases', float)])

data = np.recfromcsv("Source_data_for_CFR_vaccine_map_abridged.csv", delimiter=',', dtype=dt)

diseases = []

with open(file) as f:
    
    reader = csv.reader(f)
    
    next(reader)
    
    for row in reader:
        diseases.append(float(row[i]))
    

lats, lons = [], []

with open(file) as f:
    
    reader = csv.reader(f)
    
    next(reader)
    
    for row in reader:
        lats.append(float(row[4]))
        lons.append(float(row[5]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-709bf2c520fd> in <module>()
#       3 dt = np.dtype([('category', 'U15'), ('lat', float), ('long', float), ('cases', float)])
#       4
# ----> 5 data = np.recfromcsv("Source_data_for_CFR_vaccine_map_abridged.csv", delimiter=',', dtype=dt)
#       6
#       7 diseases = []
#
# /home/corina/anaconda3/lib/python3.4/site-packages/numpy/lib/npyio.py in recfromcsv(fname, **kwargs)
#    1982     kwargs.setdefault("delimiter", ",")
#    1983     kwargs.setdefault("dtype", None)
# -> 1984     output = genfromtxt(fname, **kwargs)
#    1985
#    1986     usemask = kwargs.get("usemask", False)
#
# ...

# %%
fig = plt.figure(figsize=(14,10))
ax = plt.subplot(1,1,1)

earth = Basemap(projection='mill')

earth.drawcoastlines(color='0.50', linewidth=0.25)
earth.fillcontinents(color='0.95')

plt.title("Measles Outbreak Student Number 100549940", fontsize =12)

index = 0

while index<len(diseases):
    if diseases(index) == "Measles":
        print (lat(index), lon(index), colour = 'red', markersize = 4)
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-36253efb0c37> in <module>()
#      11 index = 0
#      12
# ---> 13 while index<len(diseases):
#      14     if diseases(index) == "Measles":
#      15         print (lat(index), lon(index), colour = 'red')
#
# NameError: name 'diseases' is not defined

# %%
fig = plt.figure(figsize=(14,10))
ax = plt.subplot(1,1,1)

earth = Basemap(projection='mill')

earth.drawcoastlines(color='0.50', linewidth=0.25)
earth.fillcontinents(color='0.95')

plt.title("Rubella Outbreak Student Number 100549940", fontsize =12)

index = 0

while index<len(diseases):
    if diseases(index) == "Rubella":
        print (lat(index), lon(index), colour = 'magenta', markersize = 4)
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-71064fd10eb9> in <module>()
#      11 index = 0
#      12
# ---> 13 while index<len(diseases):
#      14     if diseases(index) == "Rubella":
#      15         print (lat(index), lon(index), colour = 'red')
#
# NameError: name 'diseases' is not defined

# %%
fig = plt.figure(figsize=(14,10))
ax = plt.subplot(1,1,1)

earth = Basemap(projection='mill')

earth.drawcoastlines(color='0.50', linewidth=0.25)
earth.fillcontinents(color='0.95')

plt.title("Mump Outbreak Student Number 100549940", fontsize =12)

index = 0

while index<len(diseases):
    if diseases(index) == "Mumps":
        print (lat(index), lon(index), colour = 'green', markersize = 4)
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-d8181ab130c4> in <module>()
#      11 index = 0
#      12
# ---> 13 while index<len(diseases):
#      14     if diseases(index) == "Mumps":
#      15         print (lat(index), lon(index), colour = 'green', markersize = 4)
#
# NameError: name 'diseases' is not defined

# %%
fig = plt.figure(figsize=(14,10))
ax = plt.subplot(1,1,1)

earth = Basemap(projection='mill')

earth.drawcoastlines(color='0.50', linewidth=0.25)
earth.fillcontinents(color='0.95')

plt.title("Polio Outbreak Student Number 100549940", fontsize =12)

index = 0

while index<len(diseases):
    if diseases(index) == "Polio":
        print (lat(index), lon(index), colour = 'blue', markersize = 4)
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-005aefd16309> in <module>()
#      11 index = 0
#      12
# ---> 13 while index<len(diseases):
#      14     if diseases(index) == "Polio":
#      15         print (lat(index), lon(index), colour = 'blue', markersize = 4)
#
# NameError: name 'diseases' is not defined
